# %% [markdown]
# #Título de nivel 1
# ##Título de nivel 2
# ###Título de nivel 3
#
# hola, cómo estás? 😊😊
# 1. hola
# 2. Cómo
# 3. Estás
#
# * Yo
# * muy
# * bien
#
# ```
# if (condición):
#   aquí va la condición si se cumple
# else:
#   aquí va si la condición no se cumple
# ```

# %% [markdown]
# ##Saludando al mundo

# %%
print("Hola mundo 😘")
# Out:
# Hola mundo 😘

# %% [markdown]
# ##INPUT
# Input es una función, que permite ingresar datos.
#
# Posee tres funciones
# 1. Lee: Se puede ingresar información
# 2. Almacena: Guarda la información en una variable (var)
# 3. Declara: Todos los datos almacenados los vuelve string
#
# Sintaxis
# ```
# var=input(Aquí va su impresión)
# ```
# Si se desea realizar una lectura de un tipo de dato diferente a string, se debe realizar una conversión de datos.
# Para ello, coloque el tipo de dato que desea convertir, y encierre el tipo original de dato entre paréntesis.
#
# ```
# var=int(input()) #Aquí se va a transformar un dato de string a entero
# var2=float(input())#Se transforma de string a decimal
# var3=bool(input()) #Se transforma de string a booleano
# ```

# %%
nombre=input("Cómo te llamas?")
# Out:
# Cómo te llamas?Alexandra

# %%
nombre
# Out:
# 'Alexandra'

# %%
edad1=int(input(f"Cuál es tu edad, {nombre}? "))
# Out:
# Cuál es tu edad, Alexandra? 38

# %%
edad2=int(input("Cuál es la edad del compañero de al lado? "))
# Out:
# Cuál es la edad del compañero de al lado? 0

# %%
print(f"La suma de las dos edades es {edad1+edad2}")
# Out:
# La suma de las dos edades es 38
