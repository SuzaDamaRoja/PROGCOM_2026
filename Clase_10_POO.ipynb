# %% [markdown]
# <a href="https://colab.research.google.com/github/SuzaDamaRoja/PROGCOM_2026/blob/main/Clase_10_POO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Programación orientada a objetos POO
# - Paradigma de programación enfocado en crear marcos (clase) que a su vez generan instancias (objetos).
# - Está fundamentada bajo 4 principios fundamentales o pilares: **Herencia, Abstracción, Polimorfismo y Encapsulamiento**.
# - Se enfoca en crear plantillas (class) las cuales desarrollan instancias (objetos). Esos objetos hacen cosas (métodos), y tienen características propias (atributos).
# - Ventajas al implementar POO
# 1. Escalabilidad: un mismo código en diferentes app.
# 2. Seguridad: No cualquier persona tiene acceso al código.
# 3. Modularidad: El código se expresa a partir de "pedazos" (métodos).
# 4. Reusabilidad: Se puede reutilizar partes del código en lugar de generar un código nuevo.
# 5. Mantenibilidad: El código puede ser fácilmente corregido y actualizado.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Creando clases

# %%
class Edificio:
  #Constructor: Para crear atributos, __init__(parámetros)
  def __init__(self,nombre,habitacion,direccion):
    self.nombre=nombre
    self.habitacion=habitacion
    self.direccion=direccion
  #Métodos son las mismas funciones
  def mostrar_info(self):
    print(f"Nombre: {self.nombre}")
    print(f"Dirección: {self.direccion}")
    print(f"No. de habitaciones: {self.habitacion}")

class Floristeria(Edificio):#Herencia
  def __init__(self,nombre,habitacion,direccion,tipo_flores):
    super().__init__(nombre,habitacion,direccion)
    self.tipo_flores=tipo_flores

  def vender_flor(self,flor):
    if flor in self.tipo_flores:
      print(f"Se vendió una flor de tipo {flor}")
    else:
      print(f"No tengo de esa flor")

# %% [markdown]
# Creando objetos (instancia de clase)
#
# ```
# variable=clase(parámetros)
# ```

# %%
mi_floristeria=Floristeria(
  "Floristería El chamo",
  4,
  "Carrera 33, 28-15 - Bucaramanga",
  ["rosa","tulipán","lirio"]
)

# %%
mi_floristeria.mostrar_info()
# Out:
# Nombre: Floristería El chamo
# Dirección: Carrera 33,28-19 - Bucaramanga
# No. de habitaciones: 4

# %%
mi_floristeria.direccion="Carrera 33,28-19 - Bucaramanga"

# %%
class Buffet():
  #Constructor
  def __init__(self,carbohidrato,proteina,fruta,vegetal,bebida):
    self.carbohidrato=carbohidrato
    self.proteina=proteina
    self.fruta=fruta
    self.vegetal=vegetal
    self.bebida=bebida

  def elegir_comida(self,plato,cubiertos,servilleta,cant):
    desayuno={"proteína":["huevo","salchicha","pollo","carne"],
              "carbohidrato":["arepa","panqueque","pan"],
              "fruta":["banano","fresa","mango","uva"],
              "vegetal":["cebolla","aguacate","zanahoria"],
              "bebidas":["bebidas gaseosas","café","chocolate"]}
    return f"Ingreso {self.proteina} en el plato" if self.proteina	in desayuno["proteína"] else "Elija otra proteína"

# %%
pedido1=Buffet("arepa","salchicha","fresa","cebolla","café")

# %%
pedido1.elegir_comida("sí","sí","sí",2)
# Out:
# 'Lo meto en el plato'

# %%
desayuno={"proteína":["huevo","salchicha","pollo","carne"],
              "carbohidrato":["arepa","panqueque","pan"],
              "fruta":["banano","fresa","mango","uva"],
              "vegetal":["cebolla","aguacate","zanahoria"],
              "bebidas":["bebidas gaseosas","café","chocolate"]}

# %%
proteína="huevo"

# %%
if proteína	in desayuno["proteína"]:
  print("Lo meto en el plato")
else:
  print("Elija otra proteína")
# Out:
# Lo meto en el plato
