# %% [markdown]
# <a href="https://colab.research.google.com/github/SuzaDamaRoja/PROGCOM_2026/blob/main/PROGCOM_ESTRUCTURAS_DE_REPETICI%C3%93N.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ESTRUCTURA DE REPETICIÓN
# 1. for. Cuando se sabe cuántas veces se debe repetir una acción.
# 2. while. No se sabe cuántas veces se repite la acción.

# %% [markdown]
# ##1. FOR
# Sintaxis general en python
# ```
# for (variable) in (algo):
#   se repite una acción
# ```
# algo
# * in range(n): quiero repetir n veces
# * in range(CI,CF,p): Quiero repetir desde CI, hasta CF-1, con paso p
# * in (lista, diccionario): Cuando quiero iterar cada elemento dentro de la lista/diccionario
# * in enumerate (lista, diccionario): Cuando quiero iterar cada elemento dentro de la lista/diccionario

# %%
#Quiero repetir n veces
for i in range(9):
  print(f"Hay {i+1} personas en el salón")
# Out:
# Hay 1 personas en el salón
# Hay 2 personas en el salón
# Hay 3 personas en el salón
# Hay 4 personas en el salón
# Hay 5 personas en el salón
# Hay 6 personas en el salón
# Hay 7 personas en el salón
# Hay 8 personas en el salón
# Hay 9 personas en el salón

# %%
for i in range(1,10):
  print(f"Hay {i} personas en el salón")
# Out:
# Hay 1 personas en el salón
# Hay 2 personas en el salón
# Hay 3 personas en el salón
# Hay 4 personas en el salón
# Hay 5 personas en el salón
# Hay 6 personas en el salón
# Hay 7 personas en el salón
# Hay 8 personas en el salón
# Hay 9 personas en el salón

# %%
dias=int(input("Ey!! Cuántos días falta para tu cumpleaños!?"))
for cumple in range(dias,0,-1):
  print(f"Faltan {cumple} días para tu cumpleaños!!")
print("FELIZ CUMPLEAÑOS! 😘🥳🥳")
# Out:
# Ey!! Cuántos días falta para tu cumpleaños!?7
# Faltan 7 días para tu cumpleaños!!
# Faltan 6 días para tu cumpleaños!!
# Faltan 5 días para tu cumpleaños!!
# Faltan 4 días para tu cumpleaños!!
# Faltan 3 días para tu cumpleaños!!
# Faltan 2 días para tu cumpleaños!!
# Faltan 1 días para tu cumpleaños!!

# %% [markdown]
# Sintaxis en java
# ```
# for (int variable;variable=VI;variable<VF+1;variable=variable+paso){
#   Lo que se vaya a repetir
# }
# ```
# Donde variable será definida

# %% [markdown]
# #WHILE
#
# Sintaxis
# ```
# while (CI):
#   lo que se va a repetir
#   modificador de CI
# ```
# **OJO!!**
# - while arranca si CI es VERDADERA
# - modificadores de CI: pregunta, contador, acumulador, cambio de variable

# %%
c1=0
c2=0
c3=0
c4=0
nulo=0
voto=int(input("Ingrese el número de su candidato (1-3).\n0 para voto en blanco.\nIngrese su voto:  "))
if voto==1: c1=c1+1
elif voto==2: c2+=1 #c2=c2+1
elif voto==3: c3+=1
elif voto==0: c4+=1
else: nulo+=1
print(f"Total de votos:\nCandidato 1={c1}\nCandidato 2={c2}\nCandidato 3={c3}\nVoto en blanco={c4}\nVoto nulo={nulo}")
# Out:
# Ingrese el número de su candidato (1-3).
# 0 para voto en blanco.
# Ingrese su voto:  5
# Total de votos:
# Candidato 1=0
# Candidato 2=0
# Candidato 3=0
# Voto en blanco=0
# Voto nulo=1

# %%
c1=0
c2=0
c3=0
c4=0
nulo=0
votos="s"
while votos=="s":
  voto=int(input("Ingrese el número de su candidato (1-3).\n0 para voto en blanco.\nIngrese su voto:  "))
  if voto==1: c1=c1+1
  elif voto==2: c2+=1 #c2=c2+1
  elif voto==3: c3+=1
  elif voto==0: c4+=1
  else: nulo+=1
  votos=input("Hay más votos? s para si, n para no")
  votos=votos[0].lower()
  print("")
print(f"Total de votos:\nCandidato 1={c1}\nCandidato 2={c2}\nCandidato 3={c3}\nVoto en blanco={c4}\nVoto nulo={nulo}")
# Out:
# Ingrese el número de su candidato (1-3).
# 0 para voto en blanco.
# Ingrese su voto:  2
# Hay más votos? s para si, n para nos
#
# Ingrese el número de su candidato (1-3).
# 0 para voto en blanco.
# Ingrese su voto:  3
# Hay más votos? s para si, n para non
#
# Total de votos:
# Candidato 1=0
# Candidato 2=1
# Candidato 3=1
# Voto en blanco=0
# Voto nulo=0

# %%
c1=0
c2=0
c3=0
c4=0
nulo=0
votos="s"
for votantes in range(1,425):
  voto=int(input("Ingrese el número de su candidato (1-3).\n0 para voto en blanco.\nIngrese su voto:  "))
  if voto==1: c1=c1+1
  elif voto==2: c2+=1 #c2=c2+1
  elif voto==3: c3+=1
  elif voto==0: c4+=1
  else: nulo+=1
  votos=input("Hay más votos? s para si, n para no")
  votos=votos[0].lower()
  if votos=="s": break
  print("")

# %%
c=1
print("Tabla del 2")
while c<=10:
  print(f"2x{c}={2*c}")
  c+=1
# Out:
# Tabla del 2
# 2x1=2
# 2x2=4
# 2x3=6
# 2x4=8
# 2x5=10
# 2x6=12
# 2x7=14
# 2x8=16
# 2x9=18
# 2x10=20
